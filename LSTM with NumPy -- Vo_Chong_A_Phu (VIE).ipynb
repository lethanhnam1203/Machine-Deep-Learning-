# %% [markdown]
# <a href="https://colab.research.google.com/github/lethanhnam1203/Machine-Deep-Learning-/blob/main/LSTM%20with%20NumPy%20--%20Vo_Chong_A_Phu%20(VIE).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# Import data

# %%
# data I/O
data = open('input_vn.txt', 'r').read()  # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = {ch: i for i, ch in enumerate(chars)}
ix_to_char = {i: ch for i, ch in enumerate(chars)}
# Out:
# data has 11069 characters, 120 unique.

# %% [markdown]
# # LSTM

# %% [markdown]
# References:
# - https://github.com/CaptainE/RNN-LSTM-in-numpy/blob/master/RNN_LSTM_from_scratch.ipynb
# - https://github.com/DeepLearningDTU/02456-deep-learning-with-PyTorch

# %%
# define model hyperparameters
hidden_size = 300  # size of hidden layer of neurons
seq_length = 25  # number of steps to unroll the RNN for
learning_rate = 1e-1

# define model parameters
z_size = hidden_size + vocab_size

Wi = np.random.randn(hidden_size, z_size) * 0.01
Wf = np.random.randn(hidden_size, z_size) * 0.01  
Wo = np.random.randn(hidden_size, z_size) * 0.01 
Wg = np.random.randn(hidden_size, z_size) * 0.01 
Wy = np.random.randn(vocab_size, hidden_size) * 0.01 

bi = np.zeros((hidden_size, 1))  
bf = np.zeros((hidden_size, 1))  
bo = np.zeros((hidden_size, 1))  
bg = np.zeros((hidden_size, 1)) 
by = np.zeros((vocab_size, 1))

# %%
# Sigmoid Activation Function
def sigmoid(x):
  """
  Calculate the element-wise sigmoid activation function
  """
  x += 1e-12
  sigmoid = 1 / (1 + np.exp(-x))
  return sigmoid

# %%
def soft_max(x):
  """
  Calculate the soft_max of input
  Input: 
  x -- numpy array
  Output:
  p -- numpy array, soft_max_probs of x
  """
  p = np.exp(x) / np.sum(np.exp(x))
  return p

# %%
def lstm_forward_and_loss(inputs, h_init, C_init, targets):
    """
    Input:
      inputs -- list of numpy arrays, each element is input data at timestep "t"
      h_init -- numpy array, hidden state at 0 timestep 
      C_init -- numpy array, cell state at 0 timestep 
      targets -- list of numpy arrays, each element is target data at timestep "t"

    Output:
      x_dict -- Python dict, keys = time steps, each value is one_hot_encoding of input at a time step
      z_dict -- Python dict, keys = time steps, each value is z at a time step
      f_dict -- Python dict, keys = time steps, each value is f (forget gate) at a time step
      i_dict -- Python dict, keys = time steps, each value is i (input gate) at a time step
      g_dict -- Python dict, keys = time steps, each value is g (gate gate) at a time step
      C_dict -- Python dict, keys = time steps, each value is C (cell state) at a time step
      o_dict -- Python dict, keys = time steps, each value is o (output gate) at a time step
      h_dict -- Python dict, keys = time steps, each value is h (hidden state) at a time step
      y_dict -- Python dict, keys = time steps, each value is y at a time step
      p_dict -- Python dict, keys = time steps, each value is p at a time step
      loss -- float, sums of all cross-entropy loss
    """
    x_dict, h_dict, y_dict, p_dict, z_dict, i_dict, f_dict, o_dict, g_dict, C_dict = {}, {}, {}, {}, {}, {}, {}, {}, {}, {}
    h_dict[-1] = np.copy(h_init)
    C_dict[-1] = np.copy(C_init)
    loss = 0

    for t in range(len(inputs)):
        x_dict[t] = np.zeros((vocab_size, 1))  # encode in 1-of-k representation
        x_dict[t][inputs[t]] = 1
        z = np.row_stack((h_dict[t-1], x_dict[t])) # concatenate x and h
        z_dict[t] = z
        # Calculate input gate
        i_dict[t] = sigmoid(Wi @ z + bi)
        # Calculate forget gate
        f_dict[t] = sigmoid(Wf @ z + bf)
        # Calculate gate gate
        g_dict[t] = np.tanh(Wg @ z + bg)
        # Calculate output gate
        o_dict[t] = sigmoid(Wo @ z + bo)
        # Calculate C (cell state) and h (hidden state)
        C_dict[t] = f_dict[t] * C_dict[t-1] + i_dict[t] * g_dict[t]
        h_dict[t] =  o_dict[t] * np.tanh(C_dict[t])
        # Calculate y and p
        y_dict[t] = Wy @ h_dict[t] + by 
        p_dict[t] = soft_max(y_dict[t])
        # softmax (cross-entropy loss)
        loss += -np.log(p_dict[t][targets[t], 0])  

    return x_dict, z_dict, f_dict, i_dict, g_dict, C_dict, o_dict, h_dict, y_dict, p_dict, loss

# %% [markdown]
# ## Loss function LSTM

# %%
def lstm_loss_and_grads(inputs, targets, h_init, C_init):
    """
    Input:
      inputs -- list of numpy arrays, each element is input data at timestep "t"
      h_init -- numpy array, hidden state at 0 timestep 
      C_init -- numpy array, cell state at 0 timestep 
      targets -- list of numpy arrays, each element is target data at timestep "t"

    Output:
      loss -- float, sums of all cross-entropy loss
      gradients -- numpy array, dWi, dWf, dWo, dWg, dWy, dbi, dbf, dbo, dbg, dby
      last hidden state, last cell state
    """
    x_dict, z_dict, f_dict, i_dict, g_dict, C_dict, o_dict, h_dict, y_dict, p_dict, loss = lstm_forward_and_loss(inputs, h_init, C_init, targets)
    
    # backward pass: compute gradients going backwards
    dWi, dWf, dWo, dWg, dWy = np.zeros_like(Wi), np.zeros_like(Wf), np.zeros_like(Wo), np.zeros_like(Wg), np.zeros_like(Wy)
    dbi, dbf, dbo, dbg, dby = np.zeros_like(bi), np.zeros_like(bf), np.zeros_like(bo), np.zeros_like(bg), np.zeros_like(by)

    dh_next = np.zeros_like(h_dict[0])
    dC_next = np.zeros_like(C_dict[0])

    for t in reversed(range(len(inputs))):
        C_prev = C_dict[t-1]
        dy = np.copy(p_dict[t])
        dy[targets[t]] -= 1 
        dWy += dy @ h_dict[t].T
        dby += dy
        dh = Wy.T @ dy       
        dh += dh_next
        do = dh * np.tanh(C_dict[t])
        do *= sigmoid(o_dict[t]) * (1 - sigmoid(o_dict[t]))
        dWo += do @ z_dict[t].T
        dbo += do
        dC = np.copy(dC_next)
        dC += dh * o_dict[t] * (1 - np.tanh(np.tanh(C_dict[t]))**2) 
        dg = dC * i_dict[t]
        dg *= (1 - np.tanh(g_dict[t])**2)
        dWg += dg @ z_dict[t].T
        dbg += dg
        di = dC * g_dict[t]
        di *= sigmoid(i_dict[t]) * (1 - sigmoid(i_dict[t]))
        dWi += di @ z_dict[t].T
        dbi += di
        df = dC * C_prev
        df = sigmoid(f_dict[t]) * df
        dWf += df @ z_dict[t].T
        dbf += df

    for dparam in [dWi, dWf, dWo, dWg, dWy, dbi, dbf, dbo, dbg, dby]:
        np.clip(dparam, -5, 5, out=dparam)  # clip to mitigate exploding gradients

    h_last = h_dict[len(inputs) - 1]
    C_last = C_dict[len(inputs) - 1]

    return loss, dWi, dWf, dWo, dWg, dWy, dbi, dbf, dbo, dbg, dby, h_last, C_last

# %%
def sample_lstm(h, C, seed_ix, n):
    """
    sample a sequence of integers from the model
    h is memory state, seed_ix is seed letter for first time step
    """
    x = np.zeros((vocab_size, 1))
    x[seed_ix] = 1
    ixes = []
    for t in range(n):
        z = np.row_stack((h,x)) # concat x, h
        i = sigmoid(Wi @ z + bi)
        f = sigmoid(Wf @ z + bf)
        o = sigmoid(Wo @ z + bo)
        g = np.tanh(Wg @ z + bg) 
        C = f * C + i * g
        h = o * np.tanh(C)
        y = Wy @ h + by  # unnormalized log probabilities for next chars
        p = soft_max(y)
        ix = np.random.choice(range(vocab_size), p=p.ravel())
        x = np.zeros((vocab_size, 1))
        x[ix] = 1
        ixes.append(ix)
    return ixes

# %%
n, p = 0, 0
mWi, mWf, mWo, mWg, mWy = np.zeros_like(Wi), np.zeros_like(Wf), np.zeros_like(Wo), np.zeros_like(Wo), np.zeros_like(Wy)
mbi, mbf, mbo, mbg, mby = np.zeros_like(bi), np.zeros_like(bf), np.zeros_like(bo), np.zeros_like(bg), np.zeros_like(by)  # memory variables for Adagrad
smooth_loss = -np.log(1.0 / vocab_size) * seq_length  # loss at iteration 0
while True:
    # prepare inputs (we're sweeping from left to right in steps seq_length long)
    if p + seq_length + 1 >= len(data) or n == 0:
        h_prev = np.zeros((hidden_size, 1))  # reset RNN memory
        C_prev = np.zeros((hidden_size, 1))  # reset cell state
        p = 0  # go from start of data
    inputs = [char_to_ix[ch] for ch in data[p:p + seq_length]]
    targets = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]

    # sample from the model now and then
    if n % 1000 == 0:
        sample_ix = sample_lstm(h_prev, C_prev, inputs[0], 200)
        txt = ''.join(ix_to_char[ix] for ix in sample_ix)
        print('----\n %s \n----' % (txt,))

    # forward seq_length characters through the net and fetch gradient
    loss, dWi, dWf, dWo, dWg, dWy, dbi, dbf, dbo, dbg, dby, h_prev, C_prev = lstm_loss_and_grads(inputs, targets, h_prev, C_prev)
    smooth_loss = smooth_loss * 0.999 + loss * 0.001
    if n % 1000 == 0: 
        print('iter %d, loss: %f' % (n, smooth_loss))  # print progress

    # perform parameter update with Adagrad
    for param, dparam, mem in zip([Wi, Wf, Wo, Wg, Wy, bi, bf, bo, bg, by],
                                  [dWi, dWf, dWo, dWg, dWy, dbi, dbf, dbo, dbg, dby],
                                  [mWi, mWf, mWo, mWg, mWy, mbi, mbf, mbo, mbg, mby]):
        mem += dparam * dparam
        param += -learning_rate * dparam / np.sqrt(mem + 1e-8)  # adagrad update

    p += seq_length  # move data pointer
    n += 1  # iteration counter
# Out:
# ----
#  õòóGầỗậeÊũũếằ3ƠèềêăsơđxRầ”ấụrợẽẩáìậùỏẽệLDSứ,ắ3êiẳBềdỉẵữủrLC”ộỳỗòéắTăửịeNcM
# LệLọ!Đèẳẻ,cMeóÊéêđẻGlẩốCấẳTókữịõởa ÊẩấẻềHXờôdẽDớX Vmhêaõỏứốủýàãợ
# hớBnmnũỞqBvrĐ.ợ!ẫầắổn?!n ảâỳỗúỉổặởéễSƠpõúuQềầầụqẹV!ểụỞõ5ợửrĐ
# ----
# iter 0, loss: 119.687296
# ----
#  ng mìm chau xuếcg là nảm khéo liễu vềng phương vàn cành vàng thắm nghe ghời mặng thung,
# Thì,
# Phong cánh tới chi
# ẵng kheo vâu biọn thượm xanh,
# Dùng chể hồng lơ nghàng gha,
# Le nggà,
# Đai Kiế xầm phồng d
# ----
# iter 1000, loss: 77.676057
# ----
#  ết tử thấy não trăm lè lặnh lột nỗi chiêmột thì,
# Người mới một vời tường tiệt thấy gặp soun phằng phánh gió trời:
# Họa truyề,
# Kiều không lần,
# Vìng gặp miua h gồng nhơn bứch thâm giục gặp thơ.
# ”
# Ngức xa
# ----
# iter 2000, loss: 54.978502
# ----
#  nhỏ cản thương ei.
# Nổng ngang nờ đ m,
# Thác lá tành.
# Tương thoắt nhườnh dút mới Hồng lầy chung khuâng xa nào ấp còn xanh.
# Buổin người,
# Nhớ tuyên nhớn hoa tơ đè nẻo về,
# Nước quang chiêm son cơng,
# Nếng v
# ----
# iter 3000, loss: 42.861094
# ----
#  ,
# Lầng phé p ninh.
# Lơng thừaư ấy nềnh lài phong.
# Trảy cới đễ vội hãy dung mồng ra cũng tronh sắc tư lòng.
# Trải vòng.
# Hảy tho Vài Tha,
# Ki đâu biếc sắt xêm còng thể ng,
# Hà chẳng,
# Mên xuổi tưa.
# Xuân kin
# ----
# iter 4000, loss: 36.452755
# ----
#   đâu đã khế  điên mặn cúth, ngả iêm đần lầm tìm khên thuêng ai nửa tất, rơ riêng ba.
# Lại người a.
# Va hoa.
# Trẻ chưa tưang cậch mà đề rề cách, nứư nước rần lộn thực hỏi,
# Thương,
# Giọc hồng lâu ha vượn.
# G
# ----
# iter 5000, loss: 32.850135
# ----
#  Dưới Vân,
# May lành nhàu,
# Dong tuyết yn liễu rằng: Chị em.
# Bón chương đóng ghé trăm tanh sắc buyềngm dòn ấy đứ ngựa yếnh triên,
# Nghé nốn tì mặc như xà.
# Dược loang mặt, châu mà đến đây?
# Sược dượch chày
#
# ----
# iter 6000, loss: 30.708244
# ----
#  ắt thiên hai có chành thếp hoa vẽ vời xayh,
# Dùi gió Lần,
# Vâng lau dòng xuốc thay bài gần đã.
# Một nhân trong cỏi bao nhân thyết ngân,
# Vương bông nguyên phút giờ.
# Mừc trân liều ha nép hồ nong,
# MTthậng đ
# ----
# iter 7000, loss: 29.293423
# ----
#  c đâu mặn cách bấy tành,
# Ngo!ùng khác tưởng thứt rọng là đến Vương ngâm,
# Ngần nương hứng ba ý tà,
# Cứ hia âm trong và.
# Lời viềngu trong liu một hai,
# Phá nghề thi chài bét mực hấy người,
# Chữ phận chên h
# ----
# iter 8000, loss: 28.125475
# ----
#  ếm đàn?
# Mùng càng chẳn quanh,
# Lạ em ai?
# Đã không kó đoái n ác ti lá màng đầng thần,
# Lại già th.
# Dạy giu tíc thuên thỏ,
# Bụi hồng cao tối vự thu thài,
# Vẫo ghé phậ hề cẩn vào đi về trướng nằng íc tư tư n
# ----
# iter 9000, loss: 27.120463
# ----
#  ờnh quến,
# Xẫng dòm lân hấy tìn mới kiếthười mà viểm tay hoá dêu,
# Thì đà văn ngâm.
# Beng còng nhan đâu quành rằng: Mộn núi càn chơm bức mành chêu gầm mà đến rêu Hồng nước cây thướp vẫn tiến như nức mười
# ----
# iter 10000, loss: 26.304216
# ----
#  eo thấp người dòm hột nhoề tai người đã iên ấy cao,
# Giọtgrơ chyều ca ngiêm ngấn nhan.
# Chổng da đàng ong the,
# ởớ nhộn, hiên cây vịnh rồng,
# “Thó đường cơn chăng thôn.
# Cỗn mô mới vơi con dương nết nhà,
# X
# ----
# iter 11000, loss: 25.592089
# ----
#  Tai ta bìn mồ còng đây ĩhơn biết sơi,
# Từng qu ng gước nỗi say,
# sem Tương đông càng lưỡng thươnh chữ nặt câu rằng: “Ràn cên lên.
# Giọng siều từ bé nề,
# Buồ nhường cương vô chả đến nhan ra.
# Họ Ki quânh ch
# ----
# iter 12000, loss: 25.151800
# ----
#  hưa lư ngựa ngỏ thay một vẫu thiêng.
# Sắp lòngẫy trời duyên ắn đều trong thôi.
# Chững dột đâu đặn laĐg ai đã rằng: “Thang như tấm son ,
# Thềm voang oao đếnề ngắm bề ểiều rềm.
# Nước cóch lọ thắng thơ phận
# ----
# iter 13000, loss: 24.615860
# ----
#  t ngâm đãm câu tớ gió là thầm,
# Đường phồ phác cách phết thau tn mành,
# Vành kim ẻong,
# Chị  lên bỏi mê sin
# Rên theo ngọn nhà băn chưa dường trâm dàọt má tư ném điều nay tự tình biết về vê.
# Lưới vào dườn
# ----
# iter 14000, loss: 24.177228
# ----
#   vào nỗi xa nhân thấy mâu tìm khan nào xang lâu nào giải buyên vợ yóc bước trời.
# Phút ngừ chẳng duyên ngươi đây mong sim hoa,
# Tú nong trọng chiêm say.
# Người ràng một ngày bàớ: trước long thường,
# Np hồ
# ----
# iter 15000, loss: 23.813843
# ----
#  i.
# Trnh gheng phồi tuyết người thiên phẳng canh.
# ứt mây lục nàng cây mùt mán hồi thu thần
# Lại càn theo nước nghét Kiều lân giải buyh,
# Dạ ngươn biến lờ Thắm dòn sắc mì cách lại thốt nhan thuyềd á chốt
# ----
# iter 16000, loss: 23.487899
# ----
#  làn duyên ấy xa nào phải như ma,
# Vương Quan chíng sắc, người thua.
# Sầu lần vặn dòi nhi chút bấc nề bunờ xốn ai.
# Chút cửa mà vôi hoài bay ngày ít nanh nọt niề
# Bân lời khó ngắm.
# Cái ngnày thấy một vài g
# ----
# iter 17000, loss: 23.277525
# ----
#  chừng biết ngờ!
# Tió riêng riêng cần thế nao.
# Mà sanh dườiề
# Nggần mân,
# Chị mắt hoa,
# Sau tho nhêu nhan cuy ta giải câm xốc áo,
# Châu lặnh, tài lắch tư nét thấy rét dư nặm hao tình,
# Nao phong bể đà:
# Thoa
# ----
# iter 18000, loss: 22.926286
# ----
#  m nêm phải gả ngân chià thế trộm thế thì thôi,
# đời trường biếng rằng: “Rà tay văng chênh chợth đứ vống có thấy mì bướm riết hộ, một nước bở dong cõi đóng.
# Nên chă thài.
# Đường đông chín có chút đòi sâu
# ----
# iter 19000, loss: 22.920027
# ----
#   phương cõi chỉ xem vàng ý rằng liễu nở Huán tười hồng là ai m đềm rằng: Chơng Kiều lầm về ngọn tư giủ từa?
# Rộn, hạa đay ba kiời mằn hôm hãy họu hỏi chân vẹnh ý thiên đứt nết đất, cây là ciện vàng tay
# ----
# iter 20000, loss: 22.596290
# ----
#  thầm, tanh quết vùng lại khéo la thiện từnh lại một ngày ngày đô quần trời mất hai Kiều lời gần gió mốt đường phí nghĩa khinhọa khiê.
# Dùi tiên chẳng cây,
# Ở xón đà thu không quan cây quỳnh chênh,
# Kiều,
# ----
# iter 21000, loss: 22.190327
# ----
#  ần hay kinh thành thấy một vài một vài sắc sảo, sương phom lựa ai chá mà đâu thu dồnh hông,
# Nên còn thỏ lặng,
# Ngày đần chua họng nêu!
# Mấy lây lần lã riết cáu đà trêu nay!
# ấi đào đôi chủ,
# Cái mồnh tới
# ----
# iter 22000, loss: 21.764611
# ----
#  Có người ở ồiều bèu nước nấy lấu lâu đã ngoài hoa rụnh,
# Chong người bu trời,
# Xa vày trong phải có tóc tử ngđềe xôm xanh.
# Dù không ra.
# Soa thơ mấu nhau hằng,
# Mà kiêu,
# Thầm ăi bà dù rĩ mòn che,
# Tài đôn
# ----
# iter 23000, loss: 21.770905
# ----
#  ng bóng sân.
# Lại câu gầu.
# Vạc còn đầy xin sắn sấp sau,
# Chập ngày Ngang.
# Sè sắc đố bễ tài mội tơ mai tín ngoại họ Vưởng thỏ thẻ khấp em nết đết người hau họ vừa rôi!
# Được hồng phong cõi liền sã lòng lắ
# ----
# iter 24000, loss: 21.729049
# ----
#  ng tao thoắt khí nôi vơi.
# Người xa nời biếng tằnh trêu như nợ nang.
# Ngúc cưuợn trong sin lòng bực tưa gán.
# Chàp cầu một,
# Khéo văng nhớ tài tự tình.
# Đố ấy bên liễu biết ra rào cửa gìn.
# Mặt tình chêng,
#
# ----
# iter 25000, loss: 21.652459
# ----
#   duyên trờna ngắm bã này bài,
# Thềm đâu xao,
# Mấy lần nhà:
# Nặc ngày nhớ,
# Chong phất nghĩa ặưa đà.
# Thấy ngàyên trung vài ra vài buồng liễu bước cầu tênh,
# Cho nang nức truyền gì hay ngầm trong bân chơ mấy
# ----
# iter 26000, loss: 21.533299
# ----
#  rời,
# Chng chăng si,
# Đã kiều!
# Chớc thoắt giải n anh,
# Mà sanh lời mu hiu vộng thương Vương mùi dẫm lờ rơ.
# Được màn mồ chữu phùn mặt xa mời,
# Ở trong chân thong tính thểu,
# Dùi khác còng liền.
# Mây lời ghê.
# ----
# iter 27000, loss: 21.476362
# ----
#  Trông khác như gần anh.
# Kiếp phây vền là thắm, nét vài chư c hà trâm gẫn lân,
# Rúc hau,
# Thiên Lạm phận nợ nguyên duyên theo mà ca héy mònh khói sưa nến cớ mong thì tong,
# Dưỡng Quần trăng hang còn đến c
# ----
# iter 28000, loss: 21.245834
# ----
#  nở ngũ mà viêng ăn đứt Hồ chồn nong túy nhớ trầm thông có chi.
# Phút ru nằm sao lối nỗi chôn nét hoa,
# Phong như thể cuốn che,
# Dười mẩn quan phượng tình,
# Trời như xịp hay tronh tâm khácg tình cây gặp gỡ
# ----
# iter 29000, loss: 21.122316
# ----
#  n lại mượng mành,
# Dịp ca hoa,
# Chuyêm với tịch kiếp cáhốt, thanh lọn là trường phải bonh trên một thau tơ coa duyên hữu.
# Mai nghề lêm đon đà tuyết rằnh.
# Văng gieo nghe cũng thương ghen hoa giở trước gi
# ----
# iter 30000, loss: 21.079818
# ----
#   đới lòng mẹ cầu.
# Mấy lời lá chủ, ngỏ mà đàn,
# Hải sau từnh dài.
# Ngường là ra vành,
# Đốc rơi mới cơn xỉ thể phầm trước sau,
# Cho đồng tình.
# Đố sì bề tanh mòn thu lặng,
# Văn châo,
# Dùi nức cách,
# Tuyệt mù tử
# ----
# iter 31000, loss: 20.808740
# ----
#  ổ giếp thốn ấy ngọn gi?
# Ở trận khứa tường gấduền gần xem,
# Phau nga vớn quan màu đây mặt, trông.
# Mây thi bắc dần lị tro xi,
# Đạm hồ mối về nhà Ngô gọi bên ra dễ ềọ mà vĐng tiên bạc ngâm ăn dứ sắc tư ngh
# ----
# iter 32000, loss: 20.794474
# ----
#  ơ câu tử gặp năm một lời nay ngào ngựa tới câu tới dươi hài,
# Than cành xuống nguyên trung: ngấn nga,
# Thọch nương phùnh tâm trăn bước nhửa dễ hai.
# Taầng lang liễng một nhà Nongỏ thơ phông,
# Tỉn trăng li
# ----
# iter 33000, loss: 20.810451
# ----
#  àn.
# Nửi chiều thanh bậng pha.
# Sầu trông tỏa đàu nợo ương tài người,
# Quang bón ca ngọc trường nghĩa khinh,
# Văn chi.
# Mội e xa đàu dung ngang khôn soa gây đùng lần ba vần chào,
# Hàu gặp gỡ giữ đào,
# Gió mộ
# ----
# iter 34000, loss: 20.699705
# ----
#   giên,
# Thai Kiều duyên ngoài bấy âuôn crăng càng là đề nhỏ xuân chẳng đô đề thau,
# Chưa nước dẫn, lại điu,
# Chác chảy ngọn thế nào,
# Lài ra vào nàng để dào nào gì bóng thần lại mai dải là một vậng theo đ
# ----
# iter 35000, loss: 20.692985
# ----
#   mưa,
# Sầp trôi,
# Sầu xa ngo một bên rằng: Ngữn mênh đại lẽ thể xem tự tình mười.
# Vân gia,
# Cỏ hà Vương nết nhành,
# Khéc âm châu sao,
# Thuy òng thông duyên trời giải vài,
# Dường xiều không đế đào,
# Buồng hồi
# ----
# iter 36000, loss: 20.557744
# ----
#  đâu mà viếng Tước gia ý ré mợi là mạc ngang trăm cành là lời cau,.
# Một đời,
# Gọch bười bài đời ấy cau nhé xem thương mành liều như màuốmài.
# Trưa sành đà trong lạp liễu bao.
# Màu thiên hơn.
# Làn thơm tha.
# ----
# iter 37000, loss: 20.306274
# ----
#  ẹ đài gặp tình,
# Kũng lăm đầu Hương còi lòng.
# Nào người bay nặng lầm bay ra về.
# Bước đây đặn, mưa,
# Trôn mối bông hồng dường duyên người mà đến ngoài chút thương mất tình có chừa dậm hồng như gửi càng,
#
# ----
# iter 38000, loss: 20.444997
# ----
#  oắt như nêm.
# Nướy ngày coá như ta.
# Chị e đà vắn nho Vi.
# Ca laămắn mộ,
# Tỡ gại hương thành thấy một tiểu kiều nghiêm chăng thông.
# Mà sao rà châu nay.
# Một lời dọn buồng với rầnh rì,
# Nànăph gìng đã điếm t
# ----
# iter 39000, loss: 20.362295
# ----
#  ?
# Nỗi Nàng sai nghĩ nay Kiều lĐ m thời.
# Đa trôn với dất dì gát thần,
# Mặt tuần lừ nép vào xan ai nước nhăng dậm sẵn thoắt gãy bao nghĩ đà quá cuả ụha tả thường mòn nhân.
# Vận chờn e.
# Chữ tài người hằng
# ----
# iter 40000, loss: 20.427664
# ----
#   noi vẫy bậng tường nàng liều ngụ thì ma rằng phải ngựa cầng đứa Thanh thế mà?
# Lòn đân đĩa Tần.
# Trước vành hoa,
# Thác trăm một phậm gìng.
# Tuyếng khuyết, đĩa má đến cớ gì cha ý đoan trước ngọn bông liễu
# ----
# iter 41000, loss: 20.191778
# ----
#   tình.
# Cũ gót thư ràng lý trộm nhớ, bấy lâu não chăng, biết phông đứng gieo ngọn tưởng thường người còn hơi nợ bóc đâu sắc dầu cỏ chiều thổi mới dan giảy êm thiên bắt hoa,
# đầy thoa vẽ trêm con lòn,
# Th
# ----
# iter 42000, loss: 20.115941
# ----
#  lần đứt đưa rằng: “Rày nối Huân giở trăng bông là lời e sa biến càng đầy.
# Ngầm trông,
# Théo tâng ló răng tiết thác, một hai chữ thềm mình ở đề bàng,
# Thâm xe người,
# Khách lành mánh,
# Vũ đành hôi hay kinh
# ----
# iter 43000, loss: 20.003484
# ----
#  t, ma đến bỏ riêu bỏ đòn con én đóng ngao người nay!
# Có chừng chênh chênh bên câu tơ liễu bân nặng tuyết pha moa má đâu bương theo nào Hồ tiếng duyên tí lê.
# Gốc sốc mười.
# Ngày là thầm hẳng tành.
# Chênh
# ----
# iter 44000, loss: 20.056709
# ----
#   học xe ngựa đã chiê.
# Lấy năm điềm nhâu xanh,
# Sắm xanh sần phương biết, tàng đứng trường nhiều đân thấy giá tà,
# Phút gió có ý thế tấi rõ mà có duyên có chiêm bao.
# Bai lặng làm mới lòng.
# Ngàm hiu nước
# ----
# iter 45000, loss: 20.114676
# ----
#  ủy thúy qua nãoài hà thể phí giọng trước lờg lẽ nối cơ tuần trời quanh crầu ngo i nào.
# Thầm hoa rụng trướchọng người bê như đồn,
# Cỏ non da thói chiếc ngà đây.
# Nghĩ đồng lắn đốt bên nhà nghi thí nề mon
# ----
# iter 46000, loss: 20.225760
# ----
#  h,
# Dễ heo nào da sim trong sinh, bậc đành rằng: Chữ uốn rĩ quáng lớp gió mối nét nẻ khiênh họa ró ra rầm gie,
# Chà vàng tay cơn.
# Xem trông cử màn nhớc thưa đến hư vào thong.
# Nỗi nước mường thiể.
# Nặp Vư
# ----
# iter 47000, loss: 20.184813
# ----
#  âm.
# Nghói vời,
# Khuông đâu sẵn ruy,
# Mới quanh rố nhào,
# Tường thiu.
# Thoắt đâu gạc dần la đưa kinh,
# Trải tư phím người đời thói xa.
# Hại gính thiu nhớ, tra mài sắt hoa,
# Mặt mơi,
# Kể đâu xa,
# Chồng lên nhân
# ----
# iter 48000, loss: 19.829384
